# %% [markdown]
# #Numpy
#
# Going through Numpuy intro
#
# [Numpy_Documentation](https://numpy.org/doc/)

# %%
#pip3 install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
np.__version__

list1 = [10, 20, 30]
list1
# Out:
# [10, 20, 30]

# %%
type(list1)

arr1 = np.array([10,20,30])

type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape
#(3,) 3 columns in one dimension
# Out:
# (3,)

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
arr1 * 2
arr1.sum()
# Out:
# 60

# %%
list2 = [40,50,60]
list1 = [10,20,30]
arr2dim = np.array([list1, list2])
arr2dim
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
arr2dim.shape
# Out:
# (2, 3)

# %%
arr2dim[0]
# Out:
# 10

# %%
#row based
arr2dim[0:][0]
#column based 
arr2dim[:, 0]
# Out:
# array([10, 40])
